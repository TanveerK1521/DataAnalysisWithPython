# %% [markdown]
# ### LOADING DATA

# %%
import pandas as pd
import numpy as np
data = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_base.csv'
df = pd.read_csv(data, header = None)
df.columns  = ["Manufacturer", "Category", "Screen", "GPU", "OS", "CPU_core", "Screen_Size_inch", "CPU_frequency", "RAM_GB", "Storage_GB_SSD", "Weight_kg" , "Price"]
df.head()
# Out:
#   Manufacturer  Category     Screen  GPU  OS  CPU_core Screen_Size_inch  \
# 0         Acer         4  IPS Panel    2   1         5            35.56
# 1         Dell         3    Full HD    1   1         3           39.624
# 2         Dell         3    Full HD    1   1         7           39.624
# 3         Dell         4  IPS Panel    2   1         5           33.782
# 4           HP         4    Full HD    2   1         7           39.624
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD Weight_kg  Price
# 0            1.6       8             256       1.6    978
# 1            2.0       4             256       2.2    634
# 2            2.7       8             256       2.2    946
# 3            1.6       8             128      1.22   1244
# 4            1.8       8             256      1.91    837

# %%
df = df.replace('?', np.NaN)
df.head(50)
# Out:
#    Manufacturer  Category     Screen  GPU  OS  CPU_core Screen_Size_inch  \
# 0          Acer         4  IPS Panel    2   1         5            35.56
# 1          Dell         3    Full HD    1   1         3           39.624
# 2          Dell         3    Full HD    1   1         7           39.624
# 3          Dell         4  IPS Panel    2   1         5           33.782
# 4            HP         4    Full HD    2   1         7           39.624
# 5          Dell         3    Full HD    1   1         5           39.624
# 6            HP         3    Full HD    3   1         5           39.624
# 7          Acer         3  IPS Panel    2   1         5             38.1
# 8          Dell         3    Full HD    1   1         5           39.624
# 9          Acer         3  IPS Panel    3   1         7             38.1
# 10         Dell         3    Full HD    1   1         7           39.624
# 11           HP         3    Full HD    2   1         3           39.624
# ...

# %%
#To find out shape, total rows and columns 
df1.shape
# Out:
# (238, 12)

# %%
# printing the datatypes of all columns
df.dtypes
# Out:
# Manufacturer         object
# Category              int64
# Screen               object
# GPU                   int64
# OS                    int64
# CPU_core              int64
# Screen_Size_inch     object
# CPU_frequency       float64
# RAM_GB                int64
# Storage_GB_SSD        int64
# Weight_kg            object
# Price                 int64
# dtype: object

# %%
# printing statistical description of the dataset
df.describe(include = 'all')
# Out:
#        Manufacturer    Category   Screen         GPU          OS    CPU_core  \
# count           238  238.000000      238  238.000000  238.000000  238.000000
# unique           11         NaN        2         NaN         NaN         NaN
# top            Dell         NaN  Full HD         NaN         NaN         NaN
# freq             71         NaN      161         NaN         NaN         NaN
# mean            NaN    3.205882      NaN    2.151261    1.058824    5.630252
# std             NaN    0.776533      NaN    0.638282    0.235790    1.241787
# min             NaN    1.000000      NaN    1.000000    1.000000    3.000000
# 25%             NaN    3.000000      NaN    2.000000    1.000000    5.000000
# 50%             NaN    3.000000      NaN    2.000000    1.000000    5.000000
# 75%             NaN    4.000000      NaN    3.000000    1.000000    7.000000
# max             NaN    5.000000      NaN    3.000000    2.000000    7.000000
#
# ...

# %%
# summary info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      238 non-null    object
#  1   Category          238 non-null    int64
#  2   Screen            238 non-null    object
#  3   GPU               238 non-null    int64
#  4   OS                238 non-null    int64
#  5   CPU_core          238 non-null    int64
#  6   Screen_Size_inch  234 non-null    object
#  7   CPU_frequency     238 non-null    float64
#  8   RAM_GB            238 non-null    int64
#  9   Storage_GB_SSD    238 non-null    int64
#  10  Weight_kg         233 non-null    object
#  11  Price             238 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 22.4+ KB

# %% [markdown]
# ### DATA WRANGLING
# The main purpose of data wrangling is to convert data from intial format to a format which is better for analysis

# %%
# rounding column of screen-size
df[['Screen_Size_inch']] = np.round(df[['Screen_Size_inch']],2)
df[['Screen_Size_inch']]
# Out:
#     Screen_Size_inch
# 0              35.56
# 1             39.624
# 2             39.624
# 3             33.782
# 4             39.624
# ..               ...
# 233            35.56
# 234           33.782
# 235            30.48
# 236           39.624
# 237            35.56
#
# [238 rows x 1 columns]

# %%
# EVALUATING FOR MISSING DATA
missing_data = df.isnull()
missing_data.head()
# Out:
#    Manufacturer  Category  Screen    GPU     OS  CPU_core  Screen_Size_inch  \
# 0         False     False   False  False  False     False             False
# 1         False     False   False  False  False     False             False
# 2         False     False   False  False  False     False             False
# 3         False     False   False  False  False     False             False
# 4         False     False   False  False  False     False             False
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          False   False           False      False  False
# 1          False   False           False      False  False
# 2          False   False           False      False  False
# 3          False   False           False      False  False
# 4          False   False           False      False  False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print('')
# SO the missing data is
# Screen_Size_Inch: 4 Missing data
# Weight_kg: 5 missing data
# Out:
# Manufacturer
# Manufacturer
# False    238
# Name: count, dtype: int64
#
# Category
# Category
# False    238
# Name: count, dtype: int64
#
# Screen
# Screen
# False    238
# Name: count, dtype: int64
#
# GPU
# GPU
# False    238
# Name: count, dtype: int64
#
# OS
# OS
# False    238
# Name: count, dtype: int64
#
# CPU_core
# CPU_core
# False    238
# Name: count, dtype: int64
#
# Screen_Size_inch
# Screen_Size_inch
# False    234
# True       4
# Name: count, dtype: int64
#
# CPU_frequency
# CPU_frequency
# False    238
# Name: count, dtype: int64
#
# RAM_GB
# RAM_GB
# False    238
# Name: count, dtype: int64
#
# Storage_GB_SSD
# Storage_GB_SSD
# False    238
# Name: count, dtype: int64
#
# Weight_kg
# Weight_kg
# False    233
# True       5
# Name: count, dtype: int64
#
# Price
# Price
# False    238
# Name: count, dtype: int64

# %%
# replacing missing info with Mean in Weight_kg because it is a countinous variables
avg_weight = df['Weight_kg'].astype('float').mean(axis=0)
avg_weight
# Out:
# 1.8622317596566522

# %%
df["Weight_kg"].replace(np.nan, avg_weight, inplace=True)

# %%
# now replacing missing values in Screen_Size_inch with most frequent value since it is a categorical variable
common_screen_size = df['Screen_Size_inch'].value_counts().idxmax()
common_screen_size
# Out:
# '39.624'

# %%
df['Screen_Size_inch'].replace(np.nan, common_screen_size, inplace=True)

# %%
df.dtypes
# Out:
# Manufacturer         object
# Category              int64
# Screen               object
# GPU                   int64
# OS                    int64
# CPU_core              int64
# Screen_Size_inch     object
# CPU_frequency       float64
# RAM_GB                int64
# Storage_GB_SSD        int64
# Weight_kg            object
# Price                 int64
# dtype: object

# %%
# Fixing data types
df[['Screen_Size_inch']] = df[['Screen_Size_inch']].astype('float')
df[['Weight_kg']] = df[['Weight_kg']].astype('float')

# %%
df.dtypes
# Out:
# Manufacturer         object
# Category              int64
# Screen               object
# GPU                   int64
# OS                    int64
# CPU_core              int64
# Screen_Size_inch    float64
# CPU_frequency       float64
# RAM_GB                int64
# Storage_GB_SSD        int64
# Weight_kg           float64
# Price                 int64
# dtype: object

# %%
# DATA STANDARDIZATION
#changing units of weight in kg into pounds

df[['Weight_kg' ]] = df[["Weight_kg"]]*2.205
df.rename(columns={'Weight_kg':'Weight_pounds'}, inplace=True)

# %%
# Normalize the column CPU_frequency
df['CPU_frequency'] = df['CPU_frequency']/df['CPU_frequency'].max()
df['CPU_frequency']
# Out:
# 0      0.551724
# 1      0.689655
# 2      0.931034
# 3      0.551724
# 4      0.620690
#          ...
# 233    0.896552
# 234    0.827586
# 235    0.896552
# 236    0.862069
# 237    0.793103
# Name: CPU_frequency, Length: 238, dtype: float64

# %%
# BINNING
# Create 3 bins for attribute price
# low medium and high

bins = np.linspace(min(df['Price']), max(df['Price']), 4)
group_names = ['Low', 'Medium', 'High']
df['price-binned'] = pd.cut(df['Price'],bins,labels=group_names,include_lowest=True)
df[['Price','price-binned']].head(5)
# Out:
#    Price price-binned
# 0    978          Low
# 1    634          Low
# 2    946          Low
# 3   1244          Low
# 4    837          Low

# %%
#Plot bar graph
import matplotlib.pyplot as plt

plt.bar(group_names,df['price-binned'].value_counts())
plt.xlabel("Price")
plt.ylabel("count")
plt.title("Price bins")
# Out:
# Text(0.5, 1.0, 'Price bins')

# %%
#Indicator Variable: Screen
dummy_variable_1 = pd.get_dummies(df["Screen"])
dummy_variable_1.rename(columns={'IPS Panel':'Screen-IPS_panel', 'Full HD':'Screen-Full_HD'}, inplace=True)
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "Screen" from "df"
df.drop("Screen", axis = 1, inplace=True)

# %%
df.head()
# Out:
#   Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inch  CPU_frequency  \
# 0         Acer         4    2   1         5            35.560       0.551724
# 1         Dell         3    1   1         3            39.624       0.689655
# 2         Dell         3    1   1         7            39.624       0.931034
# 3         Dell         4    2   1         5            33.782       0.551724
# 4           HP         4    2   1         7            39.624       0.620690
#
#    RAM_GB  Storage_GB_SSD  Weight_pounds  Price price-binned  Screen-Full_HD  \
# 0       8             256        3.52800    978          Low           False
# 1       4             256        4.85100    634          Low            True
# 2       8             256        4.85100    946          Low            True
# 3       8             128        2.69010   1244          Low           False
# 4       8             256        4.21155    837          Low            True
#
#    Screen-IPS_panel
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
# VISUALIZING INDIVIDUAL FEATURES
import seaborn as sns
# countinous feature variables can be best visualized with regplots(scatterplot with fitted line of regression)
# CPU_frequency with Price
sns.regplot(x='CPU_frequency', y='Price', data=df)
# Out:
# <Axes: xlabel='CPU_frequency', ylabel='Price'>

# %%
sns.regplot(x='Screen_Size_inch', y='Price', data=df)
# Out:
# <Axes: xlabel='Screen_Size_inch', ylabel='Price'>

# %%
sns.regplot(x='Weight_pounds', y='Price', data=df)
# Out:
# <Axes: xlabel='Weight_pounds', ylabel='Price'>

# %%
# Now finding out correlation values of these three attributes
df[['CPU_frequency','Price']].corr()
# correlation value is 0.36
# We can conclude that CPU frequency is 36 percent positivley correlated with price
# Out:
#                CPU_frequency     Price
# CPU_frequency       1.000000  0.366666
# Price               0.366666  1.000000

# %%
df[['Screen_Size_inch','Price']].corr()
#correlation value is -0.11
# Out:
#                   Screen_Size_inch     Price
# Screen_Size_inch          1.000000 -0.110644
# Price                    -0.110644  1.000000

# %%
df[['Weight_pounds','Price']].corr()
#correlation value is -0.050
# Out:
#                Weight_pounds     Price
# Weight_pounds       1.000000 -0.050312
# Price              -0.050312  1.000000

# %%
# CATEGORICAL VARIABLES/ATTRIBUTES can be best visualized by box plots
sns.boxplot(x='Category',y='Price',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
sns.boxplot(x='GPU',y='Price',data=df)
# Out:
# <Axes: xlabel='GPU', ylabel='Price'>

# %%
sns.boxplot(x='OS',y='Price',data=df)
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %%
sns.boxplot(x='CPU_core',y='Price',data=df)
# Out:
# <Axes: xlabel='CPU_core', ylabel='Price'>

# %%
sns.boxplot(x='RAM_GB',y='Price',data=df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %%
sns.boxplot(x='Storage_GB_SSD',y='Price',data=df)
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='Price'>

# %%
#DESCRIPTIVE STATISTICAL ANALYSIS
df.describe(include ='all')
# Out:
#        Manufacturer    Category         GPU          OS    CPU_core  \
# count           238  238.000000  238.000000  238.000000  238.000000
# unique           11         NaN         NaN         NaN         NaN
# top            Dell         NaN         NaN         NaN         NaN
# freq             71         NaN         NaN         NaN         NaN
# mean            NaN    3.205882    2.151261    1.058824    5.630252
# std             NaN    0.776533    0.638282    0.235790    1.241787
# min             NaN    1.000000    1.000000    1.000000    3.000000
# 25%             NaN    3.000000    2.000000    1.000000    5.000000
# 50%             NaN    3.000000    2.000000    1.000000    5.000000
# 75%             NaN    4.000000    3.000000    1.000000    7.000000
# max             NaN    5.000000    3.000000    2.000000    7.000000
#
#         Screen_Size_inch  CPU_frequency      RAM_GB  Storage_GB_SSD  \
# count         238.000000     238.000000  238.000000      238.000000
# ...

# %%
# GROUPBY AND PIVOT TABLES
# Group the parameters 'GPU', 'CPU_core' and 'Price' to make a pivot table and visualize the connection using pcolor plot
df_grouped= df[['GPU','CPU_core','Price']]
group = df_grouped.groupby(['GPU','CPU_core'],as_index=False).mean()
print(group)
# Out:
#    GPU  CPU_core        Price
# 0    1         3   769.250000
# 1    1         5   998.500000
# 2    1         7  1167.941176
# 3    2         3   785.076923
# 4    2         5  1462.197674
# 5    2         7  1744.621622
# 6    3         3   784.000000
# 7    3         5  1220.680000
# 8    3         7  1945.097561

# %%
# now create a pivot table
grouped_pivot = group.pivot(index='GPU',columns='CPU_core')
print(grouped_pivot)
# Out:
#                Price
# CPU_core           3            5            7
# GPU
# 1         769.250000   998.500000  1167.941176
# 2         785.076923  1462.197674  1744.621622
# 3         784.000000  1220.680000  1945.097561

# %%
#plot p color plot
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

fig.colorbar(im)

# %%
# Find pearson correlation and p-values
from scipy import stats
for param in ['RAM_GB','CPU_frequency','Storage_GB_SSD','Screen_Size_inch','Weight_pounds','CPU_core','OS','GPU','Category']:
    pearson_coef, p_value = stats.pearsonr(df[param], df['Price'])
    print(param)
    print("The Pearson Correlation Coefficient for ",param," is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# RAM_GB
# The Pearson Correlation Coefficient for  RAM_GB  is 0.5492972971857842  with a P-value of P = 3.681560628842986e-20
# CPU_frequency
# The Pearson Correlation Coefficient for  CPU_frequency  is 0.366665558925886  with a P-value of P = 5.5024633507134316e-09
# Storage_GB_SSD
# The Pearson Correlation Coefficient for  Storage_GB_SSD  is 0.24342075521810297  with a P-value of P = 0.00014898923191724212
# Screen_Size_inch
# The Pearson Correlation Coefficient for  Screen_Size_inch  is -0.11064420817118284  with a P-value of P = 0.08853397846830667
# Weight_pounds
# The Pearson Correlation Coefficient for  Weight_pounds  is -0.05031225837751546  with a P-value of P = 0.43976938534338944
# CPU_core
# The Pearson Correlation Coefficient for  CPU_core  is 0.45939777733551157  with a P-value of P = 7.912950127009089e-14
# OS
# The Pearson Correlation Coefficient for  OS  is -0.22172980114827395  with a P-value of P = 0.0005696642559246697
# GPU
# ...
